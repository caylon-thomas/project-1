# %%
# dependencies
import random
import pandas as pd
import requests
import json
import numpy as np
import glob
import matplotlib.pyplot as plt
import json

# %%
# Google developer API key
from config import gkey

# Configure gmaps
gmaps.configure(api_key=gkey)
print(gkey)

# %%
# combine all capital bikeshare csv into one mega csv = 4GB

path = "all_files/2018"
all_files = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_18 = []

for file_ in all_files:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_18.append(df)
frame = pd.concat(list_18)
frame.to_csv("all_files/2018_merged.csv", index=False)

# %%
# broke out csvs to teammates to pull 10000 per quarter random sample. Mine = 2015 to 2016

filename = "all_files/2010-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 40000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2010.csv", index=False)

filename = "all_files/2011-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 40000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2011.csv", index=False)

filename = "all_files/2012Q1-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2012Q1.csv", index=False)

filename = "all_files/2012Q2-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2012Q2.csv", index=False)

filename = "all_files/2012Q3-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2012Q3.csv", index=False)

filename = "all_files/2012Q4-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2012Q4.csv", index=False)

filename = "all_files/2013Q1-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2013Q1.csv", index=False)

filename = "all_files/2013Q2-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2013Q2.csv", index=False)

filename = "all_files/2013Q3-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2013Q3.csv", index=False)

filename = "all_files/2013Q4-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2013Q4.csv", index=False)

filename = "all_files/2014Q1-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2014Q1.csv", index=False)

filename = "all_files/2014Q2-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2014Q2.csv", index=False)

filename = "all_files/2014Q3-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2014Q3.csv", index=False)

filename = "all_files/2014Q4-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2014Q4.csv", index=False)

filename = "all_files/2015Q1-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df = pd.read_csv(filename, skiprows=skip)
df.to_csv("sample_files/2015Q1.csv", index=False)

filename = "all_files/2015Q2-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df2 = pd.read_csv(filename, skiprows=skip)
df2.to_csv("sample_files/2015Q2.csv", index=False)

filename = "all_files/2015Q3-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df3 = pd.read_csv(filename, skiprows=skip)
df3.to_csv("sample_files/2015Q3.csv", index=False)

filename = "all_files/2015Q4-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df4 = pd.read_csv(filename, skiprows=skip)
df4.to_csv("sample_files/2015Q4.csv", index=False)

filename = "all_files/2016Q1-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df5 = pd.read_csv(filename, skiprows=skip)
df5.to_csv("sample_files/2016Q1.csv", index=False)

filename = "all_files/2016Q2-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df6 = pd.read_csv(filename, skiprows=skip)
df6.to_csv("sample_files/2016Q2.csv", index=False)

filename = "all_files/2016Q3-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df7 = pd.read_csv(filename, skiprows=skip)
df7.to_csv("sample_files/2016Q3.csv", index=False)

filename = "all_files/2016Q4-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df8 = pd.read_csv(filename, skiprows=skip)
df8.to_csv("sample_files/2016Q4.csv", index=False)

filename = "all_files/2017Q1-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df5 = pd.read_csv(filename, skiprows=skip)
df5.to_csv("sample_files/2017Q1.csv", index=False)

filename = "all_files/2017Q2-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df6 = pd.read_csv(filename, skiprows=skip)
df6.to_csv("sample_files/2017Q2.csv", index=False)

filename = "all_files/2017Q3-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df7 = pd.read_csv(filename, skiprows=skip)
df7.to_csv("sample_files/2017Q3.csv", index=False)

filename = "all_files/2017Q4-capitalbikeshare-tripdata.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 10000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df8 = pd.read_csv(filename, skiprows=skip)
df8.to_csv("sample_files/2017Q4.csv", index=False)

filename = "all_files/2018_merged.csv"
#number of records in file (excludes header)
n = sum(1 for line in open(filename)) - 1 
#desired sample size
s = 20000 
#the 0-indexed header will not be included in the skip list
skip = sorted(random.sample(range(1,n+1),n-s)) 
df8 = pd.read_csv(filename, skiprows=skip)
df8.to_csv("sample_files/2018Q1_2.csv", index=False)

# %%
# combine all sample csvs into smaller mega csv
path = "sample_files"
all_files = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_18 = []

for file_ in all_files:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_18.append(df)
frame = pd.concat(list_18)
frame.to_csv("AllYears_Samples.csv", index=False)

# %%
# read in mini mega csv and bike location csv. need the lat and lng from the bike location csv

AllYears_Samples = "AllYears_Samples.csv"
AllYears_Samples = pd.read_csv(AllYears_Samples,index_col=None, header=0)
# AllYears_Samples.head(2)

bike_location_file = "bike_station_location.csv"
bike_location_df = pd.read_csv(bike_location_file,index_col=None, header=0)
# bike_location_df.head(2)

# %%
# left joins to bring in the lat and lng into the sample csv from the bike locaiton.
# 2 left joins for the start station and the end station

bike_renamed_df = bike_location_df.rename(columns={"TERMINAL_NUMBER":"Start station number"})
# bike_renamed_df.head(2)

merge_table = pd.merge(AllYears_Samples, bike_renamed_df, on="Start station number", how="left")
# merge_table.head(2)

merge_table_some_col = merge_table[['Duration', 'Start date', 'End date', 'Start station number', 
                                'Start station', 'End station number', 'End station', 'Bike number',
                                'Member type', 'ADDRESS', 'LATITUDE', 'LONGITUDE']]
# merge_table_some_col.head(2)

merge_table_rename = merge_table_some_col.rename(columns={'Duration': 'Duration', 'Start date': 'Start date', 
                                                           'End date': 'End date', 'Start station number': 'Start station number', 
                                                           'Start station': 'Start station', 'LATITUDE' : 'Start Station Lat', 
                                                           'LONGITUDE': 'Start Station Lng', 'End station number': 'End station number', 
                                                           'End station': 'End station', 'Bike number': 'Bike number',
                                                           'Member type': 'Member type'
                                                          })
merge_table_rename.head()

renamed_df2 = bike_renamed_df.rename(columns={"Start station number" : "End station number"})
# renamed_df2.head(2)

merge_table2 = pd.merge(merge_table_rename, renamed_df2, on="End station number", how="left")
merge_table2.head()

# %%
merge_table2.columns

# %%
df = merge_table2[['Duration', 'Start date', 'End date', 'Start station number','Start station', 'Start Station Lat', 'Start Station Lng',                                       'End station number', 'End station', 'LATITUDE', 'LONGITUDE','Bike number','Member type', 'LOCKED', 'INSTALL_DATE', 'REMOVAL_DATE','NUMBER_OF_BIKES']]
df.head()

# %%
# output csv
df.to_csv("AllYears_lat&lng_sample.csv", index=False)

# %%
# break out dates to have additional columns for year, month, date, and time

df = df[['Duration', 'Start date', 'End date', 'Start station number','Start station', 'Start station lat', 
         'Start station lng', 'End station number', 'End station', 'End station lat', 'End station lng', 
         'Bike number', 'number of bikes','Member type']]
df.head(2)

df['Year'] = df["End date"].str[:4]
df['Month'] = df['End date'].str[5:7]
df['Date'] = df["End date"].str[:10]
df['Time_Hr'] = df["End date"].str[11:13]
df.head()

# %%
# organize columns

df.columns
df = df[['Duration', 'Start date', 'End date', 'Year', 'Month', 'Date', 'Time_Hr','Start station number','Start station', 'Start station lat', 
         'Start station lng', 'End station number', 'End station', 'End station lat', 'End station lng', 
         'Bike number', 'number of bikes','Member type']]
df.head(2)

# %%
# output
df.to_csv("AllYrs_samples_lat&lng_time.csv", index=False)

# %%
df['End station number'].value_counts()

# %% [markdown]
# I wanted to see the difference from the Sample set vs the actual full dataset but after a bit, decided to break out the csvs into years. Before I kept on having the kernel either die or take forever to run through a 4GB csv

# %%
# dependencies
import random
import pandas as pd
import requests
import json
import numpy as np
import glob
import matplotlib.pyplot as plt
import json

# %%
# read in csvs
filename_10 = "2010AllYrs_lat&lng_time.csv"
df_10 = pd.read_csv(filename_10, index_col=None, header=0, low_memory=False)

filename_11 = "2011AllYrs_lat&lng_time.csv"
df_11 = pd.read_csv(filename_11, index_col=None, header=0, low_memory=False)

filename_12 = "2012AllYrs_lat&lng_time.csv"
df_12 = pd.read_csv(filename_12, index_col=None, header=0, low_memory=False)

filename_13 = "2013AllYrs_lat&lng_time.csv"
df_13 = pd.read_csv(filename_13, index_col=None, header=0, low_memory=False)

filename_14 = "2014AllYrs_lat&lng_time.csv"
df_14 = pd.read_csv(filename_14, index_col=None, header=0, low_memory=False)

filename_15 = "2015AllYrs_lat&lng_time.csv"
df_15 = pd.read_csv(filename_15, index_col=None, header=0, low_memory=False)

filename_16 = "2016AllYrs_lat&lng_time.csv"
df_16 = pd.read_csv(filename_16, index_col=None, header=0, low_memory=False)

filename_17 = "2017AllYrs_lat&lng_time.csv"
df_17 = pd.read_csv(filename_17, index_col=None, header=0, low_memory=False)

filename_18 = "2018AllYrs_lat&lng_time.csv"
df_18= pd.read_csv(filename_18, index_col=None, header=0, low_memory=False)

# I wanted to see the end of the dataset
df_18.head(-5)

# %%
# change over the years
change_10=df_10.groupby('Year')['Month'].count()
change_11=df_11.groupby('Year')['Month'].count()
change_12=df_12.groupby('Year')['Month'].count()
change_13=df_13.groupby('Year')['Month'].count()
change_14=df_14.groupby('Year')['Month'].count()
change_15=df_15.groupby('Year')['Month'].count()
change_16=df_16.groupby('Year')['Month'].count()
change_17=df_17.groupby('Year')['Month'].count()
change_18=df_18.groupby('Year')['Month'].count()

change_10=pd.DataFrame(change_10)
change_11=pd.DataFrame(change_11)
change_12=pd.DataFrame(change_12)
change_13=pd.DataFrame(change_13)
change_14=pd.DataFrame(change_14)
change_15=pd.DataFrame(change_15)
change_16=pd.DataFrame(change_16)
change_17=pd.DataFrame(change_17)
change_18=pd.DataFrame(change_18)

plt.figure(figsize=(10,8))
plt.bar(change_10.index, change_10['Month'], label='y-2010', align="center", alpha=0.5)
plt.bar(change_11.index, change_11['Month'], label='y-2011', align="center", alpha=0.5)
plt.bar(change_12.index, change_12['Month'], label='y-2012', align="center", alpha=0.5)
plt.bar(change_13.index, change_13['Month'], label='y-2013', align="center", alpha=0.5)
plt.bar(change_14.index, change_14['Month'], label='y-2014', align="center", alpha=0.5)
plt.bar(change_15.index, change_15['Month'], label='y-2015', align="center", alpha=0.5)
plt.bar(change_16.index, change_16['Month'], label='y-2016', align="center", alpha=0.5)
plt.bar(change_17.index, change_17['Month'], label='y-2017', align="center", alpha=0.5)
plt.bar(change_18.index, change_18['Month'], label='y-2018', align="center", alpha=0.5)

plt.xlim(2009.5,2018.5)
plt.legend(loc="upper left")
plt.xlabel("Years")
plt.ylabel("Visits")
plt.title('Visits by Year')
plt.tight_layout()
plt.savefig("years1.png")
plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
change_over_months_10=df_10.groupby('Month')['Date'].count()
change_over_months_11=df_11.groupby('Month')['Date'].count()
change_over_months_12=df_12.groupby('Month')['Date'].count()
change_over_months_13=df_13.groupby('Month')['Date'].count()
change_over_months_14=df_14.groupby('Month')['Date'].count()
change_over_months_15=df_15.groupby('Month')['Date'].count()
change_over_months_16=df_16.groupby('Month')['Date'].count()
change_over_months_17=df_17.groupby('Month')['Date'].count()
change_over_months_18=df_18.groupby('Month')['Date'].count()

plt.figure(figsize=(12,6))
plt.plot(change_over_months_10.index, change_over_months_10.values, label="y-2010", linewidth = 4, color='#0C1EA2')
plt.plot(change_over_months_11.index, change_over_months_11.values, label="y-2011", linewidth = 4, color='#136FA8')
plt.plot(change_over_months_12.index, change_over_months_12.values, label="y-2012", linewidth = 4, color='#3592CA')
plt.plot(change_over_months_13.index, change_over_months_13.values, label="y-2013", linewidth = 4, color='#91F7FD')
plt.plot(change_over_months_14.index, change_over_months_14.values, label="y-2014", linewidth = 4, color='#9BFD91')
plt.plot(change_over_months_15.index, change_over_months_15.values, label="y-2015", linewidth = 4, color='#26E47B')
plt.plot(change_over_months_16.index, change_over_months_16.values, label="y-2016", linewidth = 4, color='#10BF5F')
plt.plot(change_over_months_17.index, change_over_months_17.values, label="y-2017", linewidth = 4, color='#066C34')
plt.plot(change_over_months_18.index, change_over_months_18.values, label="y-2018", linewidth = 4, color='#053D20')

plt.xticks(np.arange(0, 13, 1))

plt.legend(loc="best")
plt.xlabel("Months")
plt.ylabel("Visits")
plt.title('Visits by Year over Months')

plt.tight_layout()
plt.savefig("months.png")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
change_time_10=df_10.groupby('Time_hr')['Date'].count()
change_time_11=df_11.groupby('Time_hr')['Date'].count()
change_time_12=df_12.groupby('Time_hr')['Date'].count()
change_time_13=df_13.groupby('Time_hr')['Date'].count()
change_time_14=df_14.groupby('Time_hr')['Date'].count()
change_time_15=df_15.groupby('Time_hr')['Date'].count()
change_time_16=df_16.groupby('Time_hr')['Date'].count()
change_time_17=df_17.groupby('Time_hr')['Date'].count()
change_time_18=df_18.groupby('Time_hr')['Date'].count()

plt.figure(figsize=(12,6))
plt.plot(change_time_10.index, change_time_10.values, label="y-2010", linewidth = 4)
plt.plot(change_time_11.index, change_time_11.values, label="y-2011", linewidth = 4)
plt.plot(change_time_12.index, change_time_12.values, label="y-2012", linewidth = 4)
plt.plot(change_time_13.index, change_time_13.values, label="y-2013", linewidth = 4)
plt.plot(change_time_14.index, change_time_14.values, label="y-2014", linewidth = 4 )
plt.plot(change_time_15.index, change_time_15.values, label="y-2015", linewidth = 4 )
plt.plot(change_time_16.index, change_time_16.values, label="y-2016", linewidth = 4 )
plt.plot(change_time_17.index, change_time_17.values, label="y-2017", linewidth = 4 )
plt.plot(change_time_18.index, change_time_18.values, label="y-2018", linewidth = 4 )

plt.xticks(np.arange(0, 25, 1))
plt.axvline(8)
plt.axvline(18)
plt.legend(loc="best")
plt.xlabel("Hours")
plt.ylabel("Visits")
plt.title('During the Day/Night starting from 0 dark 30')

plt.tight_layout()
plt.savefig("time.png")

plt.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
mappy1 = df.loc[(df["End station number"].value_counts()),
                  ["End station number", 'End station lat', 'End station lng']]
mappy1.head()

# %%
locations = mappy1[["End station lat", "End station lng"]]
rating = mappy1.index.astype(float)

# %%
fig = gmaps.figure(map_type="HYBRID")

# Create heat layer
heat_layer = gmaps.heatmap_layer(locations, weights=rating, 
                                 dissipating=False, max_intensity=10000,
                                 point_radius=.0015)

fig.add_layer(heat_layer)
plt.savefig("PNG/heatmap1.png")
fig

# %% [markdown]
# ![image.png](attachment:image.png)
