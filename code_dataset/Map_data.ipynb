# %%
import pandas as pd
import os
import gmaps
import numpy

# Google developer API key
from config import gkey

# Access maps with unique API key
gmaps.configure(api_key=gkey)


csv_path = "Capital_Bike_Share_Locations.csv"
capital_bikeshare = pd.read_csv(csv_path)

capital_bikeshare.head()
# Out:
#     OBJECTID  ID                                    ADDRESS  TERMINAL_NUMBER  \
# 0  222374669  63          Ward Circle / American University            31301
# 1  222374670  64               Wisconsin Ave & Newark St NW            31302
# 2  222374671  65  14th St Heights / 14th & Crittenden St NW            31402
# 3  222374672  66                          Anacostia Library            31804
# 4  222374673  67            Pennsylvania & Minnesota Ave SE            31805
#
#     LATITUDE  LONGITUDE INSTALLED LOCKED  INSTALL_DATE  REMOVAL_DATE  \
# 0  38.938736 -77.087171       YES     NO           NaN           NaN
# 1  38.934881 -77.072755       YES     NO           NaN           NaN
# 2  38.947774 -77.032818       YES     NO           NaN           NaN
# 3  38.865784 -76.978400       YES     NO           NaN           NaN
# 4  38.873057 -76.971015       YES     NO           NaN           NaN
#
#   TEMPORARY_INSTALL  NUMBER_OF_BIKES  NUMBER_OF_EMPTY_DOCKS              X  \
# ...

# %%
df = capital_bikeshare

newdf = capital_bikeshare[df.columns[4:6]]
#print(newdf.head())


listtest = newdf.values

# %%
# Customize the size of the figure
figure_layout = {
    'width': '600px',
    'height': '300px',
    'border': '1px solid black',
    'padding': '1px',
    'margin': '0 auto 0 auto'
}
fig = gmaps.figure(layout=figure_layout)

# %%
# Assign the marker layer to a variable
markers = gmaps.marker_layer(listtest)
# Add the layer to the map
fig.add_layer(markers)
fig
# Out:
# Figure(layout=FigureLayout(border='1px solid black', height='300px', margin='0 auto 0 auto', padding='1px', wi…
