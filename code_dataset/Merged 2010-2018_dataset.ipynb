# %%
import random
import pandas as pd
import requests
import json
import numpy as np
import glob

path = "foursets"
all_files = glob.glob(path + "/*.csv")
frame = pd.DataFrame()
list_15_16 = []

for file_ in all_files:
    df = pd.read_csv(file_,index_col=None, header=0)
    list_15_16.append(df)
frame = pd.concat(list_15_16)
frame.to_csv("almostallfiles.csv", index=False)
# Out:
# /Users/caylonthomas/anaconda3/envs/pythonexample2/lib/python3.6/site-packages/ipykernel_launcher.py:16: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=True'.
#
# To retain the current behavior and silence the warning, pass sort=False
#
#   app.launch_new_instance()

# %%
#frame['Year'] = frame["Start date"].str[6:]
frame.head()
# Out:
#   Bike number  Duration         End date                    End station  \
# 0      W00742      1012  9/20/2010 11:43                  4th & M St SW
# 1      W00803      1487  9/20/2010 12:44                  1st & M St NE
# 2      W00821       387  9/20/2010 13:27              27th & Crystal Dr
# 3      W00833      1409  9/20/2010 13:46  19th St & Pennsylvania Ave NW
# 4      W01034      1238  9/20/2010 13:48              26th & S Clark St
#
#    End station number Member type       Start date             Start station  \
# 0               31108      Member  9/20/2010 11:27  M St & New Jersey Ave SE
# 1               31603      Member  9/20/2010 12:19  Minnesota Ave Metro/DOES
# 2               31009      Member  9/20/2010 13:20         27th & Crystal Dr
# 3               31100      Member  9/20/2010 13:22             5th & K St NW
# 4               31012      Member  9/20/2010 13:28         20th & Crystal Dr
#
#    Start station number  Unnamed: 0    Year
# ...

# %%
frame.drop(columns=['Unnamed: 0'])
frame.head()
# Out:
#   Bike number  Duration         End date                    End station  \
# 0      W00742      1012  9/20/2010 11:43                  4th & M St SW
# 1      W00803      1487  9/20/2010 12:44                  1st & M St NE
# 2      W00821       387  9/20/2010 13:27              27th & Crystal Dr
# 3      W00833      1409  9/20/2010 13:46  19th St & Pennsylvania Ave NW
# 4      W01034      1238  9/20/2010 13:48              26th & S Clark St
#
#    End station number Member type       Start date             Start station  \
# 0               31108      Member  9/20/2010 11:27  M St & New Jersey Ave SE
# 1               31603      Member  9/20/2010 12:19  Minnesota Ave Metro/DOES
# 2               31009      Member  9/20/2010 13:20         27th & Crystal Dr
# 3               31100      Member  9/20/2010 13:22             5th & K St NW
# 4               31012      Member  9/20/2010 13:28         20th & Crystal Dr
#
#    Start station number  Unnamed: 0    Year
# ...

# %%
frame.to_csv("almostallsets_wyears.csv", index=False)
#frame['Start date'] = pd.to_datetime
#df = pd.read_csv('data/divvy/Divvy_Trips_2013.csv')
#df['starttime'] = df['starttime'].astype('datetime64[ns]')

# %%
df = pd.read_csv("almostallsets_wyears.csv")
df.head()
# Out:
#   Bike number  Duration         End date                    End station  \
# 0      W00742      1012  9/20/2010 11:43                  4th & M St SW
# 1      W00803      1487  9/20/2010 12:44                  1st & M St NE
# 2      W00821       387  9/20/2010 13:27              27th & Crystal Dr
# 3      W00833      1409  9/20/2010 13:46  19th St & Pennsylvania Ave NW
# 4      W01034      1238  9/20/2010 13:48              26th & S Clark St
#
#    End station number Member type       Start date             Start station  \
# 0               31108      Member  9/20/2010 11:27  M St & New Jersey Ave SE
# 1               31603      Member  9/20/2010 12:19  Minnesota Ave Metro/DOES
# 2               31009      Member  9/20/2010 13:20         27th & Crystal Dr
# 3               31100      Member  9/20/2010 13:22             5th & K St NW
# 4               31012      Member  9/20/2010 13:28         20th & Crystal Dr
#
#    Start station number  Unnamed: 0    Year
# ...

# %%
df['Start date'] = df['Start date'].astype('datetime64[ns]')
df['End date'] = df['End date'].astype('datetime64[ns]')

# %%
df.head()
# Out:
#   Bike number  Duration            End date                    End station  \
# 0      W00742      1012 2010-09-20 11:43:00                  4th & M St SW
# 1      W00803      1487 2010-09-20 12:44:00                  1st & M St NE
# 2      W00821       387 2010-09-20 13:27:00              27th & Crystal Dr
# 3      W00833      1409 2010-09-20 13:46:00  19th St & Pennsylvania Ave NW
# 4      W01034      1238 2010-09-20 13:48:00              26th & S Clark St
#
#    End station number Member type          Start date  \
# 0               31108      Member 2010-09-20 11:27:00
# 1               31603      Member 2010-09-20 12:19:00
# 2               31009      Member 2010-09-20 13:20:00
# 3               31100      Member 2010-09-20 13:22:00
# 4               31012      Member 2010-09-20 13:28:00
#
#               Start station  Start station number  Unnamed: 0    Year
# 0  M St & New Jersey Ave SE                 31208         NaN  2010.0
# ...

# %%
df.dtypes
# Out:
# Bike number                     object
# Duration                         int64
# End date                datetime64[ns]
# End station                     object
# End station number               int64
# Member type                     object
# Start date              datetime64[ns]
# Start station                   object
# Start station number             int64
# Unnamed: 0                     float64
# Year                           float64
# dtype: object

# %%
df['Year'] = df['Start date'].dt.year
df.head()
# Out:
#   Bike number  Duration            End date                    End station  \
# 0      W00742      1012 2010-09-20 11:43:00                  4th & M St SW
# 1      W00803      1487 2010-09-20 12:44:00                  1st & M St NE
# 2      W00821       387 2010-09-20 13:27:00              27th & Crystal Dr
# 3      W00833      1409 2010-09-20 13:46:00  19th St & Pennsylvania Ave NW
# 4      W01034      1238 2010-09-20 13:48:00              26th & S Clark St
#
#    End station number Member type          Start date  \
# 0               31108      Member 2010-09-20 11:27:00
# 1               31603      Member 2010-09-20 12:19:00
# 2               31009      Member 2010-09-20 13:20:00
# 3               31100      Member 2010-09-20 13:22:00
# 4               31012      Member 2010-09-20 13:28:00
#
#               Start station  Start station number  Unnamed: 0  Year
# 0  M St & New Jersey Ave SE                 31208         NaN  2010
# ...

# %%
df.to_csv("alldata.csv", index=False)

# %%
capshare = df.drop(columns=['Unnamed: 0'])
capshare.head()
# Out:
#   Bike number  Duration            End date                    End station  \
# 0      W00742      1012 2010-09-20 11:43:00                  4th & M St SW
# 1      W00803      1487 2010-09-20 12:44:00                  1st & M St NE
# 2      W00821       387 2010-09-20 13:27:00              27th & Crystal Dr
# 3      W00833      1409 2010-09-20 13:46:00  19th St & Pennsylvania Ave NW
# 4      W01034      1238 2010-09-20 13:48:00              26th & S Clark St
#
#    End station number Member type          Start date  \
# 0               31108      Member 2010-09-20 11:27:00
# 1               31603      Member 2010-09-20 12:19:00
# 2               31009      Member 2010-09-20 13:20:00
# 3               31100      Member 2010-09-20 13:22:00
# 4               31012      Member 2010-09-20 13:28:00
#
#               Start station  Start station number  Year
# 0  M St & New Jersey Ave SE                 31208  2010
# 1  Minnesota Ave Metro/DOES                 31703  2010
# ...

# %%
capshare.to_csv("Capitalbikesharedata_all.csv", index=False)
