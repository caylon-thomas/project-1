# %%
# %matplotlib notebook

# %%
# Dependencies
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
# Store filepath in a variable
bike_file_one = "Capitalbikesharedata_all.csv"

# %%
# Read our Data file with the pandas library
# Not every CSV requires an encoding, but be aware this can come up
bike_file_one_df = pd.read_csv(bike_file_one)
bike_file_one_df.head()
# Out:
#   Bike number  Duration       End date                    End station  \
# 0      W00742      1012  9/20/10 11:43                  4th & M St SW
# 1      W00803      1487  9/20/10 12:44                  1st & M St NE
# 2      W00821       387  9/20/10 13:27              27th & Crystal Dr
# 3      W00833      1409  9/20/10 13:46  19th St & Pennsylvania Ave NW
# 4      W01034      1238  9/20/10 13:48              26th & S Clark St
#
#    End station number Member type     Start date             Start station  \
# 0               31108      Member  9/20/10 11:27  M St & New Jersey Ave SE
# 1               31603      Member  9/20/10 12:19  Minnesota Ave Metro/DOES
# 2               31009      Member  9/20/10 13:20         27th & Crystal Dr
# 3               31100      Member  9/20/10 13:22             5th & K St NW
# 4               31012      Member  9/20/10 13:28         20th & Crystal Dr
#
#    Start station number  Year
# 0                 31208  2010
# 1                 31703  2010
# ...

# %%
#if bike_file_one_df["year"] == '2010':
#bike_ride_2010 = bike_file_one_df[bike_file_one_df["Year"] == [2010]
#bike_ride_2010
# ave_dur_by_memtype = bike_ride_2010.groupby(["Member type"])
# val =ave_dur_by_memtype.mean()["Duration"]
# ave_dur_by_memtype
# val  

newgroup
# plot data
#fig, ax = plt.subplots(figsize=(15,7))
# use unstack()
newgroup = bike_file_one_df.groupby(['Year', 'Member type']).mean()['Duration'].unstack().plot()
newgroup.set_ylabel("Mean Usage Per Second")
newgroup.set_xlabel("Year")
plt.savefig("Pie_Fig_19.png")
plt.show()

#data.groupby(['date','type']).count()['amount'].unstack().plot(ax=ax)
#newgroup.plot(ax=ax)
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
newgroup = bike_file_one_df.groupby(['Year', 'Member type']).count()['Duration'].unstack().plot()
newgroup.set_ylabel("Count of Member Type")
newgroup.set_xlabel("Year")
plt.savefig("Pie_Fig_20.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
# splitting complete bike ride dataframe by year
# bike_file_by_year_df = bike_file_one_df.groupby('Year')
# bike_file_by_year_df.head()
bike_file_one_df["month"] = bike_file_one_df["Start date"].str[5:7]

groupedMonths = bike_file_one_df.groupby(['Year','month','Member type']).count()['Duration']
newgroup = groupedMonths.unstack().plot()
plt.savefig("Pie_Fig_21.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
bike_file_one_df.groupby(['Year','month','Member type']).count()['Duration'].head(100)
# Out:
# Year  month  Member type
# 2010  /1     Casual          6042
#              Member         21916
#              Unknown            3
#       10     Casual          2199
#              Member          9840
# 2011  /1     Casual          1084
#              Member          5727
#       1      Casual          1857
#              Member          6457
#       11     Casual          5014
#              Member         19861
# 2012  /1     Casual          1078
#              Member          5749
#       12     Casual          4483
#              Member         20174
#       2      Casual          1565
#              Member          6951
# 2013  /1     Casual           953
#              Member          5668
#       13     Casual          4892
#              Member         20091
#       3      Casual          1715
#              Member          6681
# 2014  /1     Casual           994
#              Member          5816
#       14     Casual          5106
#              Member         19615
# ...

# %%
#creating individual dataframes for 2010
bike_ride_2010 = bike_file_by_year_df.get_group(2010)
#bike_ride_2010.head()
ave_ride_dur_2010 = bike_ride_2010.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2010
# Out:
# Member type
# Casual     3208.276787
# Member      751.687996
# Unknown     247.333333
# Name: Duration, dtype: float64

# %%
# Build Pie Chart
plt.figure(1) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold', 'lightskyblue', 'lightcoral']
explode = (0, 0, 0.1)
pie_chart_10 = ave_ride_dur_2010.plot.pie(subplots=True,explode = explode, colors = colors, autopct='%1.1f%%', figsize=(6, 5), shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2010')
plt.savefig("Pie_Fig_10.png")
plt.show()

#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2011
bike_ride_2011 = bike_file_by_year_df.get_group(2011)
#bike_ride_2011.head()
ave_ride_dur_2011 = bike_ride_2011.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2011
# Build Pie Chart
plt.figure(2) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0, 0.1)
pie_chart_11 = ave_ride_dur_2011.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2011')
plt.savefig("Pie_Fig_11.png")
plt.show()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2012
bike_ride_2012 = bike_file_by_year_df.get_group(2012)
#bike_ride_2012.head()
ave_ride_dur_2012 = bike_ride_2012.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2012
# Build Pie Chart
plt.figure(3) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0,0.1)
pie_chart_12 = ave_ride_dur_2012.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2012')
plt.savefig("Pie_Fig_12.png")
plt.show()
#plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2013
bike_ride_2013 = bike_file_by_year_df.get_group(2013)
#bike_ride_2013.head()
ave_ride_dur_2013 = bike_ride_2013.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2013
# Build Pie Chart
plt.figure(4) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0,0.1)
pie_chart_13 = ave_ride_dur_2013.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2013')
plt.savefig("Pie_Fig_13.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2014
bike_ride_2014 = bike_file_by_year_df.get_group(2014)
#bike_ride_2014.head()
ave_ride_dur_2014 = bike_ride_2014.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2014
# Build Pie Chart
plt.figure(5) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0,0.1)
pie_chart_14 = ave_ride_dur_2014.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2014')
plt.savefig("Pie_Fig_14.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2015
bike_ride_2015 = bike_file_by_year_df.get_group(2015)
#bike_ride_2015.head()
ave_ride_dur_2015 = bike_ride_2015.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2015
# Build Pie Chart
plt.figure(6) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0,0.1)
pie_chart_15 = ave_ride_dur_2015.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2015')
plt.savefig("Pie_Fig_15.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2016
bike_ride_2016 = bike_file_by_year_df.get_group(2016)
#bike_ride_2016.head()
ave_ride_dur_2016 = bike_ride_2016.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2016
# Build Pie Chart
plt.figure(7) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0,0.1)
pie_chart_16 = ave_ride_dur_2016.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2016')
plt.savefig("Pie_Fig_16.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2017
bike_ride_2017 = bike_file_by_year_df.get_group(2017)
#bike_ride_2017.head()
ave_ride_dur_2017 = bike_ride_2017.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2017
# Build Pie Chart
plt.figure(8) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0,0.1)
pie_chart_17 = ave_ride_dur_2017.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2017')
plt.savefig("Pie_Fig_17.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
#creating individual dataframes for 2018
bike_ride_2018 = bike_file_by_year_df.get_group(2018)
#bike_ride_2018.head()
ave_ride_dur_2018 = bike_ride_2018.groupby(["Member type"]).mean()["Duration"]
ave_ride_dur_2018
# Build Pie Chart
plt.figure(9) # choose figure i to be the current figure (create it if not already existing)
colors = ['gold','lightskyblue']
explode = (0,0.1)
pie_chart_18 = ave_ride_dur_2018.plot.pie(subplots=True, explode = explode, colors = colors, figsize=(6, 5), autopct='%1.1f%%', shadow=True, startangle=180)
plt.title('Average Ride Duration by Member Type 2018')
plt.savefig("Pie_Fig_18.png")
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="639.9999630089984">

# %%
ave_ride_dur_2010
ave_ride_dur_2011
ave_ride_dur_2012
ave_ride_dur_2013
ave_ride_dur_2014
ave_ride_dur_2015
ave_ride_dur_2016
ave_ride_dur_2017
ave_ride_dur_2018

# %%
urban_cities = city_ride_data[city_ride_data["type"] == "Urban"]
urban_ride_count = urban_cities.groupby(["city"]).count()["ride_id"]
urban_avg_fare = urban_cities.groupby(["city"]).mean()["fare"]
urban_driver_count = urban_cities.groupby(["city"]).mean()["driver_count"]
